# %%
use_tensorboard = True

if use_tensorboard:
    from torch.utils.tensorboard import SummaryWriter
    writer = SummaryWriter()

# %%
train_langevine = False
mixed_sampling = True

# %%
import argparse
import json
import logging
import random
from datetime import datetime
from importlib import import_module
from itertools import chain
from os.path import join, exists

import matplotlib.pyplot as plt
import torch
import torch.backends.cudnn as cudnn
import torch.nn.parallel
import torch.optim as optim
import torch.utils.data
from torch.utils.data import DataLoader
from torch.autograd import Variable

from new.aae.pcutil import plot_3d_point_cloud
#from utils.util import find_latest_epoch, prepare_results_dir, cuda_setup, setup_logging

cudnn.benchmark = True

# %%
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        gain = torch.nn.init.calculate_gain('relu')
        torch.nn.init.xavier_uniform_(m.weight, gain)
        if m.bias is not None:
            torch.nn.init.constant_(m.bias, 0)
    elif classname.find('BatchNorm') != -1:
        torch.nn.init.constant_(m.weight, 1)
        torch.nn.init.constant_(m.bias, 0)
    elif classname.find('Linear') != -1:
        gain = torch.nn.init.calculate_gain('relu')
        torch.nn.init.xavier_uniform_(m.weight, gain)
        if m.bias is not None:
            torch.nn.init.constant_(m.bias, 0)

# %%
def get_grad_norm(parameters, norm_type=2):
    total_norm = 0
    for p in parameters:
        param_norm = p.grad.data.norm(norm_type)
        total_norm += param_norm.item() ** norm_type
    total_norm = total_norm ** (1. / norm_type)
    return total_norm

# %%
# random.seed(1234)
# torch.manual_seed(1234)
# torch.cuda.manual_seed_all(1234)

# %%
results_dir = "results/"

# %%
device = torch.device("cuda")

# %%
dataset_name = "shapenet"

# %%
from new.shapenet import ShapeNetDataset

# %%
dataset = ShapeNetDataset(root_dir="shapenet",
                          classes=["chair"])
points_dataloader = DataLoader(dataset, batch_size=16,
                               shuffle=True,
                               num_workers=8,
                               drop_last=True, pin_memory=True)

# %%
if train_langevine:
    from new.models import NetWrapper
    
    net = NetWrapper().to(device)
    net.apply(weights_init)

else:
    from new.aae.aae import Generator, Encoder
    from new.models import LangevinEncoderDecoder
    
    G =  Generator().to(device)
    E = Encoder().to(device)

    G.apply(weights_init)
    E.apply(weights_init)
    
    if mixed_sampling:
        net = LangevinEncoderDecoder(E, G)

# %%
from new.params import *
from new.utils import *

# %%
#
# Float Tensors
#
fixed_noise = torch.FloatTensor(16, z_dim)
fixed_noise.normal_(mean=0, std=0.2)
std_assumed = torch.tensor(0.2)

fixed_noise = fixed_noise.to(device)
std_assumed = std_assumed.to(device)

# %%
#
# Optimizers
#
optim_params = {
                "lr": 0.0005,
                "weight_decay": 0,
                "betas": [0.9, 0.999],
                "amsgrad": False
            }

if train_langevine:
    optE = torch.optim.Adam(net.netE.parameters(), lr = 1e-6)
    optG = torch.optim.Adam(net.netG.parameters(), **optim_params)
else:
    EG_optim = torch.optim.Adam(chain(E.parameters(), G.parameters()),
                        **optim_params)

# %%
from new.champfer_loss import ChamferLoss

reconstruction_loss = ChamferLoss().to(device)

# %%
verbose = True

# %%
from tqdm.auto import tqdm
total_step = 0

# %%
for epoch in range(400):
    start_epoch_time = datetime.now()

    if train_langevine:
        net.train()
    else:     
        G.train()
        E.train()

    total_loss = 0.0
    for i, point_data in tqdm(enumerate(points_dataloader, 1)):
#         if i > 1:
#             break
        total_step += 1

        X, _ = point_data
        X = X.to(device)

        # Change dim [BATCH, N_POINTS, N_DIM] -> [BATCH, N_DIM, N_POINTS]
        if X.size(-1) == 3:
            X.transpose_(X.dim() - 2, X.dim() - 1)

        if train_langevine:
            batch_num = X.shape[0]

            # Initialize chains
            z_g_0 = sample_p_0(n = batch_num,sig=e_init_sig, device = X.device)
            z_e_0 = sample_p_0(n = batch_num,sig=g_init_sig, device = X.device)
            
            # print("z_g_0 norm", torch.mean(torch.linalg.vector_norm(z_g_0, dim = 1)))
            # print("z_e_0 norm", torch.mean(torch.linalg.vector_norm(z_e_0, dim = 1)))

            # Langevin posterior and prior
            z_g_k = net(Variable(z_g_0), X, prior=False, verbose = verbose)
            z_e_k = net(Variable(z_e_0), prior=True, verbose = verbose)

            # reconstruction
            X_hat = net.netG(z_g_k.detach())
            loss_g = net.loss_fun(X_hat.transpose(1,2).contiguous(), X.transpose(1,2).contiguous())

            # energy prior
            en_neg = net.netE(z_e_k.detach()).mean() # TODO(nijkamp): why mean() here and in Langevin sum() over energy? constant is absorbed into Adam adaptive lr
            en_pos = net.netE(z_g_k.detach()).mean()
            loss_e = (en_pos - en_neg) / batch_num

            # Learn generator
            optG.zero_grad()
            loss_g.backward()
            
            #if args.g_is_grad_clamp:
            # grad_norm_g = get_grad_norm(net.netG.parameters())
            # torch.nn.utils.clip_grad_norm(net.netG.parameters(), 10)
            
            optG.step()
            
        
            optE.zero_grad()

            #if args.g_is_grad_clamp:
            # grad_norm_e = get_grad_norm(net.netE.parameters())
            # torch.nn.utils.clip_grad_norm(net.netE.parameters(), 10)

            loss_e.backward()
            # grad_norm_e = get_grad_norm(net.netE.parameters())
            # if args.e_is_grad_clamp:
            #    torch.nn.utils.clip_grad_norm_(net.netE.parameters(), args.e_max_norm)
            optE.step()


            if i % 30 == 0:
                print(f'[{epoch}: ({i})] '
                          f'loss_g: {loss_g.item():.4f} '
                          f'(loss_e: {loss_e.item(): .4f}'
                          f' Time: {datetime.now() - start_epoch_time}')
                
        else:
            codes, mu, logvar = E(X)
            
            if mixed_sampling:
                codes = net.reparameterize(X, mu, logvar, use_lagivine = True, verbose = True)
                X_rec = G(codes)
                loss_g = torch.mean(
                     0.05 *reconstruction_loss(X.permute(0, 2, 1) + 0.5, X_rec.permute(0, 2, 1) + 0.5))
                
                loss_e = 0.05 * torch.mean((codes - mu)**2)
                
                loss_eg = loss_g + loss_e
                
                EG_optim.zero_grad()
                #E.zero_grad()
                #G.zero_grad()

                loss_eg.backward()
                total_loss += loss_eg.item()
                EG_optim.step()
                
                if i % 5 == 0:
                    if use_tensorboard:
                        writer.add_scalar('loss/loss_eg',loss_eg.item(), total_step)
                        writer.add_scalar('loss/loss_g',loss_g.item(), total_step)
                        writer.add_scalar('loss/loss_e',loss_e.item(), total_step)
                    else:
                        print(f'[{epoch}: ({i})] '
                                  f'Loss_EG: {loss_eg.item():.4f} '
                                  f'(E loss: {loss_e.item(): .4f}'
                                  f' G loss: {loss_g.item(): .4f})'
                                  f' Time: {datetime.now() - start_epoch_time}')
                
            else:            
                X_rec = G(codes)

                loss_e = torch.mean(
                     0.05 *
                    reconstruction_loss(X.permute(0, 2, 1) + 0.5,
                                        X_rec.permute(0, 2, 1) + 0.5))

                loss_kld = -0.5 * torch.mean(
                    1 - 2.0 * torch.log(std_assumed) + logvar -
                    (mu.pow(2) + logvar.exp()) / torch.pow(std_assumed, 2))

                loss_eg = loss_e + loss_kld
                EG_optim.zero_grad()
                E.zero_grad()
                G.zero_grad()

                loss_eg.backward()
                total_loss += loss_eg.item()
                EG_optim.step()

                if i % 30 == 0:
                    print(f'[{epoch}: ({i})] '
                              f'Loss_EG: {loss_eg.item():.4f} '
                              f'(REC: {loss_e.item(): .4f}'
                              f' KLD: {loss_kld.item(): .4f})'
                              f' Time: {datetime.now() - start_epoch_time}')

    print(
        f'[{epoch}/{400}] '
        f'Loss_G: {total_loss / i:.4f} '
        f'Time: {datetime.now() - start_epoch_time}'
    )
        
    ################################### eval ######################################
    #
    # Save intermediate results
    #
    if train_langevine:
        net.eval()
        with torch.no_grad():
            fake = net.netG(fixed_noise).data.cpu().numpy()
            X_rec = X_hat.data.cpu().numpy()
            X = X.data.cpu().numpy()
    else:
        G.eval()
        E.eval()
        with torch.no_grad():
            fake = G(fixed_noise).data.cpu().numpy()
            codes, _, _ = E(X)
            X_rec = G(codes).data.cpu().numpy()
            X = X.data.cpu().numpy()

    for k in range(5):
        fig = plot_3d_point_cloud(X[k][0], X[k][1], X[k][2],
                                  in_u_sphere=True, show=False)
        fig.savefig(
            join(results_dir, 'samples', f'{epoch}_{k}_real.png'))
        plt.close(fig)

    for k in range(5):
        fig = plot_3d_point_cloud(fake[k][0], fake[k][1], fake[k][2],
                                  in_u_sphere=True, show=False,
                                  title=str(epoch))
        fig.savefig(
            join(results_dir, 'samples', f'{epoch:05}_{k}_fixed.png'))
        plt.close(fig)

    for k in range(5):
        fig = plot_3d_point_cloud(X_rec[k][0],
                                  X_rec[k][1],
                                  X_rec[k][2],
                                  in_u_sphere=True, show=False)
        fig.savefig(join(results_dir, 'samples',
                         f'{epoch}_{k}_reconstructed.png'))
        plt.close(fig)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0…
# Langevin posterior   1/ 10: LOSS G=3915.051 z_norm:   2.195
# Langevin posterior  10/ 10: LOSS G=1617.180 z_norm:   2.086
# Langevin posterior   1/ 10: LOSS G=1254.213 z_norm:   2.328
# Langevin posterior  10/ 10: LOSS G=1046.287 z_norm:   2.303
# Langevin posterior   1/ 10: LOSS G=1552.479 z_norm:   2.451
# Langevin posterior  10/ 10: LOSS G= 773.151 z_norm:   2.400
# Langevin posterior   1/ 10: LOSS G=1105.519 z_norm:   2.297
# Langevin posterior  10/ 10: LOSS G= 560.049 z_norm:   2.277
# Langevin posterior   1/ 10: LOSS G= 971.609 z_norm:   2.219
# Langevin posterior  10/ 10: LOSS G= 789.440 z_norm:   2.222
# Langevin posterior   1/ 10: LOSS G= 661.131 z_norm:   1.999
# Langevin posterior  10/ 10: LOSS G= 595.530 z_norm:   1.998
# Langevin posterior   1/ 10: LOSS G= 903.476 z_norm:   1.896
# Langevin posterior  10/ 10: LOSS G= 601.678 z_norm:   1.857
# Langevin posterior   1/ 10: LOSS G= 990.773 z_norm:   1.860
# Langevin posterior  10/ 10: LOSS G= 691.632 z_norm:   1.814
# Langevin posterior   1/ 10: LOSS G= 984.338 z_norm:   1.880
# Langevin posterior  10/ 10: LOSS G= 688.105 z_norm:   1.831
# Langevin posterior   1/ 10: LOSS G= 700.971 z_norm:   1.824
# Langevin posterior  10/ 10: LOSS G= 620.809 z_norm:   1.844
# Langevin posterior   1/ 10: LOSS G=1005.456 z_norm:   1.764
# Langevin posterior  10/ 10: LOSS G= 803.832 z_norm:   1.806
# Langevin posterior   1/ 10: LOSS G= 778.698 z_norm:   1.835
# Langevin posterior  10/ 10: LOSS G= 730.980 z_norm:   1.843
# Langevin posterior   1/ 10: LOSS G= 803.992 z_norm:   1.772
# Langevin posterior  10/ 10: LOSS G= 723.237 z_norm:   1.789
# Langevin posterior   1/ 10: LOSS G= 903.366 z_norm:   1.798
# Langevin posterior  10/ 10: LOSS G= 801.931 z_norm:   1.787
# Langevin posterior   1/ 10: LOSS G= 766.847 z_norm:   1.846
# Langevin posterior  10/ 10: LOSS G= 629.270 z_norm:   1.822
# Langevin posterior   1/ 10: LOSS G= 887.284 z_norm:   1.889
# Langevin posterior  10/ 10: LOSS G= 644.340 z_norm:   1.852
# Langevin posterior   1/ 10: LOSS G= 709.344 z_norm:   1.789
# Langevin posterior  10/ 10: LOSS G= 551.575 z_norm:   1.770
# Langevin posterior   1/ 10: LOSS G= 723.330 z_norm:   1.774
# Langevin posterior  10/ 10: LOSS G= 636.990 z_norm:   1.786
# Langevin posterior   1/ 10: LOSS G= 625.255 z_norm:   1.749
# Langevin posterior  10/ 10: LOSS G= 601.392 z_norm:   1.783
# Langevin posterior   1/ 10: LOSS G= 618.899 z_norm:   1.753
# Langevin posterior  10/ 10: LOSS G= 572.167 z_norm:   1.750
# Langevin posterior   1/ 10: LOSS G= 657.458 z_norm:   1.736
# Langevin posterior  10/ 10: LOSS G= 575.520 z_norm:   1.755
# Langevin posterior   1/ 10: LOSS G= 601.382 z_norm:   1.694
# Langevin posterior  10/ 10: LOSS G= 506.515 z_norm:   1.694
# Langevin posterior   1/ 10: LOSS G= 830.409 z_norm:   1.754
# Langevin posterior  10/ 10: LOSS G= 560.940 z_norm:   1.727
# Langevin posterior   1/ 10: LOSS G= 878.680 z_norm:   1.738
# Langevin posterior  10/ 10: LOSS G= 670.501 z_norm:   1.743
# Langevin posterior   1/ 10: LOSS G= 760.184 z_norm:   1.724
# Langevin posterior  10/ 10: LOSS G= 489.377 z_norm:   1.695
# Langevin posterior   1/ 10: LOSS G= 937.316 z_norm:   1.786
# Langevin posterior  10/ 10: LOSS G= 661.272 z_norm:   1.730
# Langevin posterior   1/ 10: LOSS G= 707.460 z_norm:   1.742
# Langevin posterior  10/ 10: LOSS G= 468.095 z_norm:   1.704
# Langevin posterior   1/ 10: LOSS G= 857.929 z_norm:   1.751
# Langevin posterior  10/ 10: LOSS G= 606.389 z_norm:   1.732
# Langevin posterior   1/ 10: LOSS G= 735.159 z_norm:   1.787
# Langevin posterior  10/ 10: LOSS G= 511.605 z_norm:   1.757
# Langevin posterior   1/ 10: LOSS G= 731.208 z_norm:   1.802
# Langevin posterior  10/ 10: LOSS G= 520.787 z_norm:   1.775
# Langevin posterior   1/ 10: LOSS G= 580.626 z_norm:   1.748
# Langevin posterior  10/ 10: LOSS G= 425.349 z_norm:   1.743
# Langevin posterior   1/ 10: LOSS G= 609.763 z_norm:   1.843
# Langevin posterior  10/ 10: LOSS G= 427.234 z_norm:   1.818
# Langevin posterior   1/ 10: LOSS G= 548.765 z_norm:   1.769
# Langevin posterior  10/ 10: LOSS G= 453.797 z_norm:   1.812
# Langevin posterior   1/ 10: LOSS G= 783.836 z_norm:   1.784
# Langevin posterior  10/ 10: LOSS G= 678.630 z_norm:   1.797
# Langevin posterior   1/ 10: LOSS G= 477.096 z_norm:   1.770
# Langevin posterior  10/ 10: LOSS G= 455.606 z_norm:   1.770
# Langevin posterior   1/ 10: LOSS G= 687.570 z_norm:   1.781
# Langevin posterior  10/ 10: LOSS G= 524.147 z_norm:   1.774
# Langevin posterior   1/ 10: LOSS G= 500.402 z_norm:   1.746
# Langevin posterior  10/ 10: LOSS G= 470.367 z_norm:   1.749
# Langevin posterior   1/ 10: LOSS G= 625.282 z_norm:   1.725
# Langevin posterior  10/ 10: LOSS G= 451.845 z_norm:   1.724
# Langevin posterior   1/ 10: LOSS G= 692.242 z_norm:   1.734
# Langevin posterior  10/ 10: LOSS G= 508.203 z_norm:   1.725
# Langevin posterior   1/ 10: LOSS G= 749.124 z_norm:   1.677
# Langevin posterior  10/ 10: LOSS G= 560.561 z_norm:   1.672
# Langevin posterior   1/ 10: LOSS G= 706.041 z_norm:   1.673
# Langevin posterior  10/ 10: LOSS G= 455.611 z_norm:   1.671
# Langevin posterior   1/ 10: LOSS G= 550.175 z_norm:   1.720
# Langevin posterior  10/ 10: LOSS G= 366.435 z_norm:   1.750
# Langevin posterior   1/ 10: LOSS G= 604.514 z_norm:   1.701
# Langevin posterior  10/ 10: LOSS G= 402.333 z_norm:   1.688
# Langevin posterior   1/ 10: LOSS G= 596.299 z_norm:   1.761
# Langevin posterior  10/ 10: LOSS G= 560.128 z_norm:   1.756
# Langevin posterior   1/ 10: LOSS G= 647.726 z_norm:   1.691
# Langevin posterior  10/ 10: LOSS G= 584.594 z_norm:   1.710
# Langevin posterior   1/ 10: LOSS G= 522.451 z_norm:   1.639
# Langevin posterior  10/ 10: LOSS G= 439.563 z_norm:   1.669
# Langevin posterior   1/ 10: LOSS G= 571.834 z_norm:   1.624
# Langevin posterior  10/ 10: LOSS G= 510.389 z_norm:   1.674
# Langevin posterior   1/ 10: LOSS G= 663.633 z_norm:   1.679
# Langevin posterior  10/ 10: LOSS G= 400.541 z_norm:   1.648
# Langevin posterior   1/ 10: LOSS G= 964.846 z_norm:   1.702
# Langevin posterior  10/ 10: LOSS G= 505.173 z_norm:   1.661
# Langevin posterior   1/ 10: LOSS G=1097.800 z_norm:   1.691
# Langevin posterior  10/ 10: LOSS G= 712.019 z_norm:   1.891
# Langevin posterior   1/ 10: LOSS G=1017.818 z_norm:   1.766
# Langevin posterior  10/ 10: LOSS G= 422.602 z_norm:   1.670
# Langevin posterior   1/ 10: LOSS G=1614.195 z_norm:   1.899
# Langevin posterior  10/ 10: LOSS G= 874.064 z_norm:   1.876
# Langevin posterior   1/ 10: LOSS G= 990.973 z_norm:   1.866
# Langevin posterior  10/ 10: LOSS G= 455.502 z_norm:   1.794
# Langevin posterior   1/ 10: LOSS G=1180.015 z_norm:   1.905
# Langevin posterior  10/ 10: LOSS G= 402.125 z_norm:   1.825
# Langevin posterior   1/ 10: LOSS G= 857.526 z_norm:   1.942
# Langevin posterior  10/ 10: LOSS G= 404.159 z_norm:   1.880
# Langevin posterior   1/ 10: LOSS G= 648.437 z_norm:   2.010
# Langevin posterior  10/ 10: LOSS G= 416.173 z_norm:   1.990
# Langevin posterior   1/ 10: LOSS G= 485.750 z_norm:   2.084
# Langevin posterior  10/ 10: LOSS G= 346.344 z_norm:   2.092
# Langevin posterior   1/ 10: LOSS G= 675.941 z_norm:   2.137
# Langevin posterior  10/ 10: LOSS G= 475.748 z_norm:   2.153
# Langevin posterior   1/ 10: LOSS G= 569.506 z_norm:   2.195
# Langevin posterior  10/ 10: LOSS G= 399.379 z_norm:   2.196
# Langevin posterior   1/ 10: LOSS G= 624.949 z_norm:   2.185
# Langevin posterior  10/ 10: LOSS G=3911.670 z_norm:   2.525
# Langevin posterior   1/ 10: LOSS G= 745.820 z_norm:   2.317
# Langevin posterior  10/ 10: LOSS G= 523.509 z_norm:   2.309
# Langevin posterior   1/ 10: LOSS G=1110.615 z_norm:   2.475
# Langevin posterior  10/ 10: LOSS G= 483.602 z_norm:   2.398
# Langevin posterior   1/ 10: LOSS G=1434.959 z_norm:   2.495
# Langevin posterior  10/ 10: LOSS G= 365.071 z_norm:   2.391
# Langevin posterior   1/ 10: LOSS G=1516.442 z_norm:   2.621
# Langevin posterior  10/ 10: LOSS G= 408.242 z_norm:   2.535
# Langevin posterior   1/ 10: LOSS G=1569.243 z_norm:   2.686
# Langevin posterior  10/ 10: LOSS G= 471.987 z_norm:   2.608
# Langevin posterior   1/ 10: LOSS G=1246.926 z_norm:   2.833
# Langevin posterior  10/ 10: LOSS G= 397.784 z_norm:   2.769
# Langevin posterior   1/ 10: LOSS G= 900.337 z_norm:   2.915
# Langevin posterior  10/ 10: LOSS G= 380.131 z_norm:   2.883
# Langevin posterior   1/ 10: LOSS G= 597.536 z_norm:   3.036
# Langevin posterior  10/ 10: LOSS G= 378.420 z_norm:   3.037
# Langevin posterior   1/ 10: LOSS G= 600.084 z_norm:   3.222
# Langevin posterior  10/ 10: LOSS G= 406.674 z_norm:   3.221
# Langevin posterior   1/ 10: LOSS G= 607.571 z_norm:   3.282
# Langevin posterior  10/ 10: LOSS G= 344.114 z_norm:   3.270
# Langevin posterior   1/ 10: LOSS G= 903.167 z_norm:   3.382
# Langevin posterior  10/ 10: LOSS G= 478.639 z_norm:   3.357
# Langevin posterior   1/ 10: LOSS G= 637.406 z_norm:   3.459
# Langevin posterior  10/ 10: LOSS G= 375.885 z_norm:   3.439
# Langevin posterior   1/ 10: LOSS G= 592.404 z_norm:   3.401
# Langevin posterior  10/ 10: LOSS G= 382.409 z_norm:   3.382
# Langevin posterior   1/ 10: LOSS G= 632.379 z_norm:   3.369
# Langevin posterior  10/ 10: LOSS G= 429.128 z_norm:   3.356
# Langevin posterior   1/ 10: LOSS G= 595.665 z_norm:   3.346
# Langevin posterior  10/ 10: LOSS G= 397.566 z_norm:   3.347
# Langevin posterior   1/ 10: LOSS G= 554.163 z_norm:   3.251
# Langevin posterior  10/ 10: LOSS G= 306.767 z_norm:   3.247
# Langevin posterior   1/ 10: LOSS G= 688.782 z_norm:   3.279
# Langevin posterior  10/ 10: LOSS G= 380.465 z_norm:   3.260
# Langevin posterior   1/ 10: LOSS G= 542.413 z_norm:   3.344
# Langevin posterior  10/ 10: LOSS G= 341.097 z_norm:   3.340
# Langevin posterior   1/ 10: LOSS G= 467.684 z_norm:   3.297
# Langevin posterior  10/ 10: LOSS G= 347.718 z_norm:   3.289
# Langevin posterior   1/ 10: LOSS G= 379.978 z_norm:   3.319
# Langevin posterior  10/ 10: LOSS G= 307.999 z_norm:   3.322
# Langevin posterior   1/ 10: LOSS G= 800.574 z_norm:   3.340
# Langevin posterior  10/ 10: LOSS G= 406.566 z_norm:   3.304
# Langevin posterior   1/ 10: LOSS G= 642.908 z_norm:   3.197
# Langevin posterior  10/ 10: LOSS G= 468.290 z_norm:   3.185
# Langevin posterior   1/ 10: LOSS G= 537.139 z_norm:   3.228
# Langevin posterior  10/ 10: LOSS G= 370.772 z_norm:   3.214
# Langevin posterior   1/ 10: LOSS G= 520.863 z_norm:   3.057
# Langevin posterior  10/ 10: LOSS G= 380.456 z_norm:   3.055
# Langevin posterior   1/ 10: LOSS G= 535.749 z_norm:   3.024
# Langevin posterior  10/ 10: LOSS G= 364.949 z_norm:   3.015
# Langevin posterior   1/ 10: LOSS G= 543.690 z_norm:   2.937
# Langevin posterior  10/ 10: LOSS G= 357.294 z_norm:   2.933
# Langevin posterior   1/ 10: LOSS G= 761.278 z_norm:   2.921
# Langevin posterior  10/ 10: LOSS G= 482.942 z_norm:   2.938
# Langevin posterior   1/ 10: LOSS G= 599.755 z_norm:   2.797
# Langevin posterior  10/ 10: LOSS G= 349.061 z_norm:   2.801
# Langevin posterior   1/ 10: LOSS G= 738.054 z_norm:   2.795
# Langevin posterior  10/ 10: LOSS G= 497.870 z_norm:   3.057
# Langevin posterior   1/ 10: LOSS G= 619.244 z_norm:   2.895
# Langevin posterior  10/ 10: LOSS G= 336.546 z_norm:   2.879
# Langevin posterior   1/ 10: LOSS G= 657.891 z_norm:   2.829
# Langevin posterior  10/ 10: LOSS G= 341.313 z_norm:   2.815
# Langevin posterior   1/ 10: LOSS G= 707.321 z_norm:   2.975
# Langevin posterior  10/ 10: LOSS G= 336.960 z_norm:   2.954
# Langevin posterior   1/ 10: LOSS G= 746.049 z_norm:   2.875
# Langevin posterior  10/ 10: LOSS G= 391.108 z_norm:   2.862
# Langevin posterior   1/ 10: LOSS G= 558.772 z_norm:   2.918
# Langevin posterior  10/ 10: LOSS G= 325.922 z_norm:   2.908
# Langevin posterior   1/ 10: LOSS G= 767.769 z_norm:   2.821
# Langevin posterior  10/ 10: LOSS G= 374.201 z_norm:   2.829
# Langevin posterior   1/ 10: LOSS G= 758.795 z_norm:   2.863
# Langevin posterior  10/ 10: LOSS G= 384.388 z_norm:   2.843
# Langevin posterior   1/ 10: LOSS G= 613.000 z_norm:   2.885
# Langevin posterior  10/ 10: LOSS G= 390.527 z_norm:   2.896
# Langevin posterior   1/ 10: LOSS G= 531.317 z_norm:   2.837
# Langevin posterior  10/ 10: LOSS G= 374.305 z_norm:   2.838
# Langevin posterior   1/ 10: LOSS G= 555.138 z_norm:   2.895
# Langevin posterior  10/ 10: LOSS G= 350.451 z_norm:   2.899
# Langevin posterior   1/ 10: LOSS G= 576.628 z_norm:   2.943
# Langevin posterior  10/ 10: LOSS G= 423.899 z_norm:   2.942
# Langevin posterior   1/ 10: LOSS G= 482.512 z_norm:   2.918
# Langevin posterior  10/ 10: LOSS G= 351.482 z_norm:   2.917
# Langevin posterior   1/ 10: LOSS G= 746.873 z_norm:   2.822
# Langevin posterior  10/ 10: LOSS G= 452.992 z_norm:   2.805
# Langevin posterior   1/ 10: LOSS G= 596.996 z_norm:   2.848
# Langevin posterior  10/ 10: LOSS G= 458.184 z_norm:   2.858
# Langevin posterior   1/ 10: LOSS G= 488.552 z_norm:   2.721
# Langevin posterior  10/ 10: LOSS G= 345.775 z_norm:   2.709
# Langevin posterior   1/ 10: LOSS G= 716.100 z_norm:   2.688
# Langevin posterior  10/ 10: LOSS G= 356.158 z_norm:   2.673
# Langevin posterior   1/ 10: LOSS G= 482.010 z_norm:   2.676
# Langevin posterior  10/ 10: LOSS G= 330.988 z_norm:   2.672
# Langevin posterior   1/ 10: LOSS G= 581.717 z_norm:   2.630
# Langevin posterior  10/ 10: LOSS G= 425.418 z_norm:   2.621
# Langevin posterior   1/ 10: LOSS G= 592.751 z_norm:   2.597
# Langevin posterior  10/ 10: LOSS G= 438.979 z_norm:   2.595
# Langevin posterior   1/ 10: LOSS G= 585.325 z_norm:   2.554
# Langevin posterior  10/ 10: LOSS G= 471.968 z_norm:   2.552
# Langevin posterior   1/ 10: LOSS G= 627.200 z_norm:   2.530
# Langevin posterior  10/ 10: LOSS G= 439.955 z_norm:   2.534
# Langevin posterior   1/ 10: LOSS G= 641.221 z_norm:   2.511
# Langevin posterior  10/ 10: LOSS G= 444.146 z_norm:   2.515
# Langevin posterior   1/ 10: LOSS G= 458.723 z_norm:   2.452
# Langevin posterior  10/ 10: LOSS G= 331.540 z_norm:   2.455
# Langevin posterior   1/ 10: LOSS G= 804.682 z_norm:   2.492
# Langevin posterior  10/ 10: LOSS G=24937.432 z_norm:   6.614
# Langevin posterior   1/ 10: LOSS G= 716.594 z_norm:   2.900
# Langevin posterior  10/ 10: LOSS G= 329.120 z_norm:   2.887
# Langevin posterior   1/ 10: LOSS G= 804.682 z_norm:   3.232
# Langevin posterior  10/ 10: LOSS G= 365.674 z_norm:   3.211
# Langevin posterior   1/ 10: LOSS G=1040.524 z_norm:   3.738
# Langevin posterior  10/ 10: LOSS G= 578.798 z_norm:   3.709
# Langevin posterior   1/ 10: LOSS G= 624.966 z_norm:   4.120
# Langevin posterior  10/ 10: LOSS G= 360.735 z_norm:   4.107
# Langevin posterior   1/ 10: LOSS G= 798.761 z_norm:   4.327
# Langevin posterior  10/ 10: LOSS G= 461.477 z_norm:   4.310
# Langevin posterior   1/ 10: LOSS G= 756.047 z_norm:   4.691
# Langevin posterior  10/ 10: LOSS G= 499.066 z_norm:   4.686
# Langevin posterior   1/ 10: LOSS G= 755.271 z_norm:   5.012
# Langevin posterior  10/ 10: LOSS G= 397.558 z_norm:   4.996
# Langevin posterior   1/ 10: LOSS G= 635.130 z_norm:   5.135
# Langevin posterior  10/ 10: LOSS G= 302.458 z_norm:   5.142
# Langevin posterior   1/ 10: LOSS G= 535.414 z_norm:   5.387
# Langevin posterior  10/ 10: LOSS G= 373.207 z_norm:   5.374
# Langevin posterior   1/ 10: LOSS G= 495.019 z_norm:   5.792
# Langevin posterior  10/ 10: LOSS G= 334.421 z_norm:   5.783
# Langevin posterior   1/ 10: LOSS G= 769.227 z_norm:   6.027
# Langevin posterior  10/ 10: LOSS G= 378.497 z_norm:   6.019
# Langevin posterior   1/ 10: LOSS G= 786.515 z_norm:   6.006
# Langevin posterior  10/ 10: LOSS G= 350.092 z_norm:   6.010
# Langevin posterior   1/ 10: LOSS G= 670.110 z_norm:   6.137
# Langevin posterior  10/ 10: LOSS G= 335.146 z_norm:   6.148
# Langevin posterior   1/ 10: LOSS G= 796.724 z_norm:   6.419
# Langevin posterior  10/ 10: LOSS G= 463.332 z_norm:   6.411
# Langevin posterior   1/ 10: LOSS G= 862.011 z_norm:   6.625
# Langevin posterior  10/ 10: LOSS G= 391.964 z_norm:   6.616
# Langevin posterior   1/ 10: LOSS G= 670.550 z_norm:   6.680
# Langevin posterior  10/ 10: LOSS G= 322.411 z_norm:   6.668
# Langevin posterior   1/ 10: LOSS G= 818.124 z_norm:   6.758
# Langevin posterior  10/ 10: LOSS G= 336.252 z_norm:   6.744
# Langevin posterior   1/ 10: LOSS G= 717.695 z_norm:   6.916
# Langevin posterior  10/ 10: LOSS G= 390.675 z_norm:   6.896
# Langevin posterior   1/ 10: LOSS G= 613.714 z_norm:   6.807
# Langevin posterior  10/ 10: LOSS G= 426.527 z_norm:   6.806
# Langevin posterior   1/ 10: LOSS G= 517.842 z_norm:   6.812
# Langevin posterior  10/ 10: LOSS G= 301.176 z_norm:   6.812
# Langevin posterior   1/ 10: LOSS G= 673.810 z_norm:   6.565
# Langevin posterior  10/ 10: LOSS G= 303.321 z_norm:   6.567
# Langevin posterior   1/ 10: LOSS G= 760.460 z_norm:   6.867
# Langevin posterior  10/ 10: LOSS G= 332.129 z_norm:   6.866
# Langevin posterior   1/ 10: LOSS G= 735.790 z_norm:   6.822
# Langevin posterior  10/ 10: LOSS G= 322.886 z_norm:   6.814
# Langevin posterior   1/ 10: LOSS G= 585.690 z_norm:   6.681
# Langevin posterior  10/ 10: LOSS G= 301.374 z_norm:   6.670
# Langevin posterior   1/ 10: LOSS G= 529.151 z_norm:   6.674
# Langevin posterior  10/ 10: LOSS G= 275.479 z_norm:   6.652
# Langevin posterior   1/ 10: LOSS G= 671.961 z_norm:   6.598
# Langevin posterior  10/ 10: LOSS G= 299.830 z_norm:   6.596
# Langevin posterior   1/ 10: LOSS G= 741.339 z_norm:   6.445
# Langevin posterior  10/ 10: LOSS G= 367.914 z_norm:   6.427
# Langevin posterior   1/ 10: LOSS G= 570.161 z_norm:   6.632
# Langevin posterior  10/ 10: LOSS G= 362.585 z_norm:   6.630
# Langevin posterior   1/ 10: LOSS G= 454.903 z_norm:   6.402
# Langevin posterior  10/ 10: LOSS G= 317.141 z_norm:   6.396
# Langevin posterior   1/ 10: LOSS G= 581.728 z_norm:   6.215
# Langevin posterior  10/ 10: LOSS G= 307.614 z_norm:   6.210
# Langevin posterior   1/ 10: LOSS G= 738.037 z_norm:   6.328
# Langevin posterior  10/ 10: LOSS G= 375.412 z_norm:   6.319
# Langevin posterior   1/ 10: LOSS G= 606.287 z_norm:   6.421
# Langevin posterior  10/ 10: LOSS G= 330.723 z_norm:   6.421
# Langevin posterior   1/ 10: LOSS G= 417.087 z_norm:   5.741
# Langevin posterior  10/ 10: LOSS G= 244.934 z_norm:   5.733
# Langevin posterior   1/ 10: LOSS G= 601.539 z_norm:   6.211
# Langevin posterior  10/ 10: LOSS G= 329.092 z_norm:   6.204
# Langevin posterior   1/ 10: LOSS G= 467.956 z_norm:   5.872
# Langevin posterior  10/ 10: LOSS G= 336.668 z_norm:   5.869
# Langevin posterior   1/ 10: LOSS G= 604.615 z_norm:   5.906
# Langevin posterior  10/ 10: LOSS G= 352.202 z_norm:   5.897
# Langevin posterior   1/ 10: LOSS G= 511.954 z_norm:   5.899
# Langevin posterior  10/ 10: LOSS G= 389.913 z_norm:   5.888
# Langevin posterior   1/ 10: LOSS G= 524.244 z_norm:   5.780
# Langevin posterior  10/ 10: LOSS G= 368.837 z_norm:   5.774
# Langevin posterior   1/ 10: LOSS G= 558.335 z_norm:   5.319
# Langevin posterior  10/ 10: LOSS G= 378.900 z_norm:   5.319
# Langevin posterior   1/ 10: LOSS G= 559.545 z_norm:   5.551
# Langevin posterior  10/ 10: LOSS G= 353.241 z_norm:   5.554
# Langevin posterior   1/ 10: LOSS G= 422.336 z_norm:   5.337
# Langevin posterior  10/ 10: LOSS G= 275.655 z_norm:   5.334
# Langevin posterior   1/ 10: LOSS G= 436.900 z_norm:   5.567
# Langevin posterior  10/ 10: LOSS G= 326.963 z_norm:   5.559
# Langevin posterior   1/ 10: LOSS G= 398.720 z_norm:   5.362
# Langevin posterior  10/ 10: LOSS G= 322.918 z_norm:   5.359
# Langevin posterior   1/ 10: LOSS G= 346.054 z_norm:   4.964
# Langevin posterior  10/ 10: LOSS G= 284.442 z_norm:   4.963
# Langevin posterior   1/ 10: LOSS G= 458.227 z_norm:   5.252
# Langevin posterior  10/ 10: LOSS G= 301.997 z_norm:   5.239
# Langevin posterior   1/ 10: LOSS G= 374.525 z_norm:   4.943
# Langevin posterior  10/ 10: LOSS G= 287.941 z_norm:   4.935
# Langevin posterior   1/ 10: LOSS G= 493.566 z_norm:   4.725
# Langevin posterior  10/ 10: LOSS G= 283.404 z_norm:   4.715
# Langevin posterior   1/ 10: LOSS G= 412.737 z_norm:   4.885
# Langevin posterior  10/ 10: LOSS G= 283.935 z_norm:   4.885
# Langevin posterior   1/ 10: LOSS G= 830.207 z_norm:   4.574
# Langevin posterior  10/ 10: LOSS G= 429.542 z_norm:   4.566
# Langevin posterior   1/ 10: LOSS G= 421.442 z_norm:   4.678
# Langevin posterior  10/ 10: LOSS G= 256.614 z_norm:   4.676
# Langevin posterior   1/ 10: LOSS G= 472.586 z_norm:   4.809
# Langevin posterior  10/ 10: LOSS G= 306.254 z_norm:   4.801
# Langevin posterior   1/ 10: LOSS G= 415.395 z_norm:   4.581
# Langevin posterior  10/ 10: LOSS G= 302.336 z_norm:   4.577
# Langevin posterior   1/ 10: LOSS G= 423.373 z_norm:   4.737
# Langevin posterior  10/ 10: LOSS G= 312.622 z_norm:   4.739
# Langevin posterior   1/ 10: LOSS G= 398.665 z_norm:   4.669
# Langevin posterior  10/ 10: LOSS G= 330.285 z_norm:   4.668
# Langevin posterior   1/ 10: LOSS G= 439.757 z_norm:   4.564
# Langevin posterior  10/ 10: LOSS G= 381.423 z_norm:   4.569
# Langevin posterior   1/ 10: LOSS G= 479.476 z_norm:   4.357
# Langevin posterior  10/ 10: LOSS G= 312.021 z_norm:   4.343
# Langevin posterior   1/ 10: LOSS G= 497.563 z_norm:   4.440
# Langevin posterior  10/ 10: LOSS G= 321.798 z_norm:   4.431
# Langevin posterior   1/ 10: LOSS G= 371.172 z_norm:   4.178
# Langevin posterior  10/ 10: LOSS G= 302.977 z_norm:   4.179
# Langevin posterior   1/ 10: LOSS G= 393.869 z_norm:   4.220
# Langevin posterior  10/ 10: LOSS G= 273.102 z_norm:   4.221
# Langevin posterior   1/ 10: LOSS G= 465.612 z_norm:   4.254
# Langevin posterior  10/ 10: LOSS G= 390.649 z_norm:   4.255
# Langevin posterior   1/ 10: LOSS G= 424.753 z_norm:   4.081
# Langevin posterior  10/ 10: LOSS G= 310.573 z_norm:   4.083
# Langevin posterior   1/ 10: LOSS G= 593.598 z_norm:   4.301
# Langevin posterior  10/ 10: LOSS G= 342.439 z_norm:   4.300
# Langevin posterior   1/ 10: LOSS G= 490.857 z_norm:   4.167
# Langevin posterior  10/ 10: LOSS G= 309.096 z_norm:   4.175
# Langevin posterior   1/ 10: LOSS G= 460.865 z_norm:   4.006
# Langevin posterior  10/ 10: LOSS G= 268.967 z_norm:   4.004
# Langevin posterior   1/ 10: LOSS G= 373.199 z_norm:   4.040
# Langevin posterior  10/ 10: LOSS G= 272.001 z_norm:   4.038
# Langevin posterior   1/ 10: LOSS G= 409.208 z_norm:   4.116
# Langevin posterior  10/ 10: LOSS G= 322.163 z_norm:   4.122
# Langevin posterior   1/ 10: LOSS G= 474.454 z_norm:   3.842
# Langevin posterior  10/ 10: LOSS G= 364.864 z_norm:   3.837
# Langevin posterior   1/ 10: LOSS G= 521.493 z_norm:   3.918
# Langevin posterior  10/ 10: LOSS G= 311.931 z_norm:   3.922
# Langevin posterior   1/ 10: LOSS G= 565.588 z_norm:   4.194
# Langevin posterior  10/ 10: LOSS G= 347.749 z_norm:   4.184
# Langevin posterior   1/ 10: LOSS G= 415.214 z_norm:   3.861
# Langevin posterior  10/ 10: LOSS G= 276.935 z_norm:   3.858
# Langevin posterior   1/ 10: LOSS G= 484.331 z_norm:   4.139
# Langevin posterior  10/ 10: LOSS G= 333.207 z_norm:   4.130
# Langevin posterior   1/ 10: LOSS G= 418.478 z_norm:   4.136
# Langevin posterior  10/ 10: LOSS G= 307.295 z_norm:   4.121
# Langevin posterior   1/ 10: LOSS G= 380.023 z_norm:   3.969
# Langevin posterior  10/ 10: LOSS G= 327.749 z_norm:   3.971
# Langevin posterior   1/ 10: LOSS G= 493.511 z_norm:   3.731
# Langevin posterior  10/ 10: LOSS G= 268.815 z_norm:   3.740
# Langevin posterior   1/ 10: LOSS G= 326.440 z_norm:   3.540
# Langevin posterior  10/ 10: LOSS G= 250.610 z_norm:   3.544
# Langevin posterior   1/ 10: LOSS G= 435.856 z_norm:   3.891
# Langevin posterior  10/ 10: LOSS G= 335.359 z_norm:   3.894
# Langevin posterior   1/ 10: LOSS G= 435.985 z_norm:   3.633
# Langevin posterior  10/ 10: LOSS G= 282.992 z_norm:   3.637
# Langevin posterior   1/ 10: LOSS G= 415.011 z_norm:   3.468
# Langevin posterior  10/ 10: LOSS G= 253.887 z_norm:   3.464
# Langevin posterior   1/ 10: LOSS G= 503.667 z_norm:   3.638
# Langevin posterior  10/ 10: LOSS G= 306.133 z_norm:   3.628
# Langevin posterior   1/ 10: LOSS G= 505.093 z_norm:   3.723
# Langevin posterior  10/ 10: LOSS G= 289.370 z_norm:   3.714
# Langevin posterior   1/ 10: LOSS G= 489.512 z_norm:   3.560
# Langevin posterior  10/ 10: LOSS G= 299.201 z_norm:   3.549
# Langevin posterior   1/ 10: LOSS G= 351.339 z_norm:   3.577
# Langevin posterior  10/ 10: LOSS G= 238.796 z_norm:   3.574
# Langevin posterior   1/ 10: LOSS G= 511.468 z_norm:   3.798
# Langevin posterior  10/ 10: LOSS G= 367.789 z_norm:   3.794
# Langevin posterior   1/ 10: LOSS G= 519.565 z_norm:   3.512
# Langevin posterior  10/ 10: LOSS G= 313.079 z_norm:   3.507
# Langevin posterior   1/ 10: LOSS G= 441.835 z_norm:   3.556
# Langevin posterior  10/ 10: LOSS G= 323.074 z_norm:   3.557
# Langevin posterior   1/ 10: LOSS G= 515.065 z_norm:   3.441
# Langevin posterior  10/ 10: LOSS G= 292.330 z_norm:   3.441
# Langevin posterior   1/ 10: LOSS G= 402.043 z_norm:   3.445
# Langevin posterior  10/ 10: LOSS G= 277.849 z_norm:   3.442
# Langevin posterior   1/ 10: LOSS G= 339.513 z_norm:   3.277
# Langevin posterior  10/ 10: LOSS G= 239.843 z_norm:   3.273
# Langevin posterior   1/ 10: LOSS G= 489.367 z_norm:   3.460
# Langevin posterior  10/ 10: LOSS G= 322.845 z_norm:   3.455
# Langevin posterior   1/ 10: LOSS G= 404.288 z_norm:   3.409
# Langevin posterior  10/ 10: LOSS G= 295.678 z_norm:   3.402
# Langevin posterior   1/ 10: LOSS G= 301.578 z_norm:   3.229
# Langevin posterior  10/ 10: LOSS G= 251.509 z_norm:   3.229
# Langevin posterior   1/ 10: LOSS G= 389.872 z_norm:   3.205
# Langevin posterior  10/ 10: LOSS G= 307.686 z_norm:   3.200
# Langevin posterior   1/ 10: LOSS G= 500.951 z_norm:   3.210
# Langevin posterior  10/ 10: LOSS G= 334.459 z_norm:   3.205
# Langevin posterior   1/ 10: LOSS G= 405.268 z_norm:   3.299
# Langevin posterior  10/ 10: LOSS G= 298.338 z_norm:   3.293
# Langevin posterior   1/ 10: LOSS G= 421.695 z_norm:   3.216
# Langevin posterior  10/ 10: LOSS G= 322.621 z_norm:   3.219
# Langevin posterior   1/ 10: LOSS G= 428.503 z_norm:   3.035
# Langevin posterior  10/ 10: LOSS G= 320.464 z_norm:   3.029
# Langevin posterior   1/ 10: LOSS G= 472.879 z_norm:   2.923
# Langevin posterior  10/ 10: LOSS G= 309.576 z_norm:   2.921
# Langevin posterior   1/ 10: LOSS G= 486.543 z_norm:   3.113
# Langevin posterior  10/ 10: LOSS G= 374.611 z_norm:   3.112
# Langevin posterior   1/ 10: LOSS G= 510.689 z_norm:   2.937
# Langevin posterior  10/ 10: LOSS G= 368.020 z_norm:   2.941
# Langevin posterior   1/ 10: LOSS G= 347.719 z_norm:   2.818
# Langevin posterior  10/ 10: LOSS G= 315.572 z_norm:   2.826
# Langevin posterior   1/ 10: LOSS G= 426.718 z_norm:   2.913
# Langevin posterior  10/ 10: LOSS G= 373.588 z_norm:   2.956
# Langevin posterior   1/ 10: LOSS G= 435.497 z_norm:   2.752
# Langevin posterior  10/ 10: LOSS G= 324.313 z_norm:   2.747
# Langevin posterior   1/ 10: LOSS G= 448.509 z_norm:   2.817
# Langevin posterior  10/ 10: LOSS G= 318.104 z_norm:   2.813
# Langevin posterior   1/ 10: LOSS G= 412.102 z_norm:   2.929
# Langevin posterior  10/ 10: LOSS G= 302.921 z_norm:   2.926
# Langevin posterior   1/ 10: LOSS G= 502.496 z_norm:   2.854
# Langevin posterior  10/ 10: LOSS G= 328.068 z_norm:   2.860
# Langevin posterior   1/ 10: LOSS G= 406.504 z_norm:   2.754
# Langevin posterior  10/ 10: LOSS G= 347.258 z_norm:   2.738
# Langevin posterior   1/ 10: LOSS G= 487.754 z_norm:   2.621
# Langevin posterior  10/ 10: LOSS G= 397.829 z_norm:   2.638
# Langevin posterior   1/ 10: LOSS G= 554.251 z_norm:   2.685
# Langevin posterior  10/ 10: LOSS G= 410.156 z_norm:   2.702
# Langevin posterior   1/ 10: LOSS G= 404.119 z_norm:   2.555
# Langevin posterior  10/ 10: LOSS G= 581.164 z_norm:   2.582
# Langevin posterior   1/ 10: LOSS G= 528.150 z_norm:   2.458
# Langevin posterior  10/ 10: LOSS G= 442.736 z_norm:   2.478
# Langevin posterior   1/ 10: LOSS G= 490.406 z_norm:   2.534
# Langevin posterior  10/ 10: LOSS G= 362.989 z_norm:   2.548
# Langevin posterior   1/ 10: LOSS G= 668.418 z_norm:   2.505
# Langevin posterior  10/ 10: LOSS G= 388.572 z_norm:   2.583
# Langevin posterior   1/ 10: LOSS G= 566.054 z_norm:   2.525
# Langevin posterior  10/ 10: LOSS G= 366.286 z_norm:   2.549
# Langevin posterior   1/ 10: LOSS G= 626.345 z_norm:   2.489
# Langevin posterior  10/ 10: LOSS G= 337.910 z_norm:   2.485
# Langevin posterior   1/ 10: LOSS G= 724.880 z_norm:   2.571
# Langevin posterior  10/ 10: LOSS G= 344.982 z_norm:   2.596
# Langevin posterior   1/ 10: LOSS G= 851.613 z_norm:   2.673
# Langevin posterior  10/ 10: LOSS G= 367.794 z_norm:   2.670
# Langevin posterior   1/ 10: LOSS G= 419.804 z_norm:   2.548
# Langevin posterior  10/ 10: LOSS G= 246.292 z_norm:   2.548
# Langevin posterior   1/ 10: LOSS G= 536.961 z_norm:   2.686
# Langevin posterior  10/ 10: LOSS G= 341.217 z_norm:   2.686
# Langevin posterior   1/ 10: LOSS G= 450.312 z_norm:   2.615
# Langevin posterior  10/ 10: LOSS G= 330.930 z_norm:   2.619
# Langevin posterior   1/ 10: LOSS G= 594.055 z_norm:   2.751
# Langevin posterior  10/ 10: LOSS G= 333.264 z_norm:   2.751
# Langevin posterior   1/ 10: LOSS G= 505.043 z_norm:   2.857
# Langevin posterior  10/ 10: LOSS G= 348.747 z_norm:   2.857
# Langevin posterior   1/ 10: LOSS G= 508.972 z_norm:   2.906
# Langevin posterior  10/ 10: LOSS G= 374.728 z_norm:   2.903
# Langevin posterior   1/ 10: LOSS G= 456.760 z_norm:   2.876
# Langevin posterior  10/ 10: LOSS G= 314.917 z_norm:   2.873
# Langevin posterior   1/ 10: LOSS G= 410.106 z_norm:   2.894
# Langevin posterior  10/ 10: LOSS G= 341.861 z_norm:   2.899
# Langevin posterior   1/ 10: LOSS G= 498.766 z_norm:   2.960
# Langevin posterior  10/ 10: LOSS G= 367.400 z_norm:   2.967
# Langevin posterior   1/ 10: LOSS G= 432.955 z_norm:   2.980
# Langevin posterior  10/ 10: LOSS G= 385.620 z_norm:   2.994
# Langevin posterior   1/ 10: LOSS G= 415.908 z_norm:   2.871
# Langevin posterior  10/ 10: LOSS G= 279.247 z_norm:   2.862
# Langevin posterior   1/ 10: LOSS G= 530.708 z_norm:   2.928
# Langevin posterior  10/ 10: LOSS G= 335.102 z_norm:   2.946
# Langevin posterior   1/ 10: LOSS G= 422.711 z_norm:   2.839
# Langevin posterior  10/ 10: LOSS G= 295.738 z_norm:   2.848
# Langevin posterior   1/ 10: LOSS G= 532.964 z_norm:   2.918
# Langevin posterior  10/ 10: LOSS G= 328.944 z_norm:   2.924
# Langevin posterior   1/ 10: LOSS G= 580.381 z_norm:   2.953
# Langevin posterior  10/ 10: LOSS G= 345.620 z_norm:   2.965
# Langevin posterior   1/ 10: LOSS G= 475.497 z_norm:   2.948
# Langevin posterior  10/ 10: LOSS G= 347.539 z_norm:   2.953
# Langevin posterior   1/ 10: LOSS G= 338.794 z_norm:   2.858
# Langevin posterior  10/ 10: LOSS G= 261.063 z_norm:   2.856
# Langevin posterior   1/ 10: LOSS G= 435.825 z_norm:   2.897
# Langevin posterior  10/ 10: LOSS G= 324.430 z_norm:   2.901
# Langevin posterior   1/ 10: LOSS G= 433.252 z_norm:   2.898
# Langevin posterior  10/ 10: LOSS G= 338.952 z_norm:   2.897
# Langevin posterior   1/ 10: LOSS G= 579.436 z_norm:   3.057
# Langevin posterior  10/ 10: LOSS G= 370.497 z_norm:   3.058
# Langevin posterior   1/ 10: LOSS G= 551.625 z_norm:   2.979
# Langevin posterior  10/ 10: LOSS G= 408.706 z_norm:   2.981
# Langevin posterior   1/ 10: LOSS G= 511.447 z_norm:   2.971
# Langevin posterior  10/ 10: LOSS G= 275.421 z_norm:   2.963
# Langevin posterior   1/ 10: LOSS G= 430.900 z_norm:   3.016
# Langevin posterior  10/ 10: LOSS G= 344.494 z_norm:   3.008
# Langevin posterior   1/ 10: LOSS G= 457.105 z_norm:   2.848
# Langevin posterior  10/ 10: LOSS G= 266.279 z_norm:   2.838
# Langevin posterior   1/ 10: LOSS G= 549.459 z_norm:   2.951
# Langevin posterior  10/ 10: LOSS G= 328.647 z_norm:   2.949
# Langevin posterior   1/ 10: LOSS G= 723.577 z_norm:   3.001
# Langevin posterior  10/ 10: LOSS G= 616.891 z_norm:   3.017
# Langevin posterior   1/ 10: LOSS G= 665.670 z_norm:   2.852
# Langevin posterior  10/ 10: LOSS G= 324.057 z_norm:   2.855
# Langevin posterior   1/ 10: LOSS G= 515.001 z_norm:   2.886
# Langevin posterior  10/ 10: LOSS G= 301.569 z_norm:   2.891
# Langevin posterior   1/ 10: LOSS G= 536.040 z_norm:   2.884
# Langevin posterior  10/ 10: LOSS G= 317.160 z_norm:   2.876
# Langevin posterior   1/ 10: LOSS G= 459.137 z_norm:   2.987
# Langevin posterior  10/ 10: LOSS G= 331.095 z_norm:   2.971
# Langevin posterior   1/ 10: LOSS G= 374.792 z_norm:   2.916
# Langevin posterior  10/ 10: LOSS G= 260.408 z_norm:   2.913
# Langevin posterior   1/ 10: LOSS G= 375.043 z_norm:   2.893
# Langevin posterior  10/ 10: LOSS G= 300.423 z_norm:   2.885
# Langevin posterior   1/ 10: LOSS G= 525.034 z_norm:   2.791
# Langevin posterior  10/ 10: LOSS G= 340.417 z_norm:   2.781
# Langevin posterior   1/ 10: LOSS G= 420.079 z_norm:   2.805
# Langevin posterior  10/ 10: LOSS G= 314.228 z_norm:   2.807
# Langevin posterior   1/ 10: LOSS G= 461.215 z_norm:   2.892
# Langevin posterior  10/ 10: LOSS G= 326.684 z_norm:   2.923
# Langevin posterior   1/ 10: LOSS G= 427.780 z_norm:   2.838
# Langevin posterior  10/ 10: LOSS G= 346.565 z_norm:   2.846
# Langevin posterior   1/ 10: LOSS G= 437.792 z_norm:   2.795
# Langevin posterior  10/ 10: LOSS G= 303.509 z_norm:   2.798
# Langevin posterior   1/ 10: LOSS G= 554.246 z_norm:   2.822
# Langevin posterior  10/ 10: LOSS G= 327.588 z_norm:   2.841
# Langevin posterior   1/ 10: LOSS G= 576.886 z_norm:   2.661
# Langevin posterior  10/ 10: LOSS G= 356.672 z_norm:   2.664
# Langevin posterior   1/ 10: LOSS G= 602.524 z_norm:   2.739
# Langevin posterior  10/ 10: LOSS G= 331.723 z_norm:   2.736
# Langevin posterior   1/ 10: LOSS G= 653.003 z_norm:   2.772
# Langevin posterior  10/ 10: LOSS G= 304.538 z_norm:   2.791
# Langevin posterior   1/ 10: LOSS G= 747.799 z_norm:   2.688
# Langevin posterior  10/ 10: LOSS G= 290.879 z_norm:   2.699
# Langevin posterior   1/ 10: LOSS G= 614.751 z_norm:   2.827
# Langevin posterior  10/ 10: LOSS G= 290.599 z_norm:   2.836
# Langevin posterior   1/ 10: LOSS G= 548.819 z_norm:   2.732
# Langevin posterior  10/ 10: LOSS G= 284.907 z_norm:   2.750
# Langevin posterior   1/ 10: LOSS G= 767.321 z_norm:   2.774
# Langevin posterior  10/ 10: LOSS G= 397.544 z_norm:   2.777
# Langevin posterior   1/ 10: LOSS G= 536.816 z_norm:   2.740
# Langevin posterior  10/ 10: LOSS G= 321.292 z_norm:   2.741
# Langevin posterior   1/ 10: LOSS G= 470.153 z_norm:   2.846
# Langevin posterior  10/ 10: LOSS G= 318.740 z_norm:   2.847
# Langevin posterior   1/ 10: LOSS G= 384.187 z_norm:   2.863
# Langevin posterior  10/ 10: LOSS G= 251.068 z_norm:   2.857
# Langevin posterior   1/ 10: LOSS G= 602.852 z_norm:   2.827
# Langevin posterior  10/ 10: LOSS G= 305.499 z_norm:   2.829
# Langevin posterior   1/ 10: LOSS G= 463.696 z_norm:   2.932
# Langevin posterior  10/ 10: LOSS G= 339.080 z_norm:   2.949
# Langevin posterior   1/ 10: LOSS G= 428.384 z_norm:   2.910
# Langevin posterior  10/ 10: LOSS G= 362.511 z_norm:   2.915
# Langevin posterior   1/ 10: LOSS G= 384.594 z_norm:   2.918
# Langevin posterior  10/ 10: LOSS G= 270.912 z_norm:   2.924
# Langevin posterior   1/ 10: LOSS G= 506.147 z_norm:   2.886
# Langevin posterior  10/ 10: LOSS G= 343.906 z_norm:   2.896
# Langevin posterior   1/ 10: LOSS G= 394.758 z_norm:   2.891
# Langevin posterior  10/ 10: LOSS G= 259.671 z_norm:   2.887
# Langevin posterior   1/ 10: LOSS G= 438.829 z_norm:   2.905
# Langevin posterior  10/ 10: LOSS G= 326.729 z_norm:   2.920
# Langevin posterior   1/ 10: LOSS G= 484.847 z_norm:   2.983
# Langevin posterior  10/ 10: LOSS G= 369.971 z_norm:   2.997
# Langevin posterior   1/ 10: LOSS G= 367.664 z_norm:   2.926
# Langevin posterior  10/ 10: LOSS G= 260.181 z_norm:   2.925
# Langevin posterior   1/ 10: LOSS G= 522.293 z_norm:   3.033
# Langevin posterior  10/ 10: LOSS G= 323.023 z_norm:   3.037
# Langevin posterior   1/ 10: LOSS G= 438.459 z_norm:   3.065
# Langevin posterior  10/ 10: LOSS G= 320.503 z_norm:   3.064
# Langevin posterior   1/ 10: LOSS G= 355.183 z_norm:   3.044
# Langevin posterior  10/ 10: LOSS G= 304.638 z_norm:   3.036
# Langevin posterior   1/ 10: LOSS G= 329.054 z_norm:   2.931
# Langevin posterior  10/ 10: LOSS G= 309.867 z_norm:   2.930
# Langevin posterior   1/ 10: LOSS G= 380.460 z_norm:   2.988
# Langevin posterior  10/ 10: LOSS G= 289.524 z_norm:   2.992
# Langevin posterior   1/ 10: LOSS G= 395.487 z_norm:   2.890
# Langevin posterior  10/ 10: LOSS G= 298.373 z_norm:   2.906
# Langevin posterior   1/ 10: LOSS G= 373.752 z_norm:   2.976
# Langevin posterior  10/ 10: LOSS G= 266.130 z_norm:   2.979
# Langevin posterior   1/ 10: LOSS G= 393.912 z_norm:   2.861
# Langevin posterior  10/ 10: LOSS G= 287.135 z_norm:   2.864
# Langevin posterior   1/ 10: LOSS G= 433.272 z_norm:   2.927
# Langevin posterior  10/ 10: LOSS G= 255.673 z_norm:   2.933
# Langevin posterior   1/ 10: LOSS G= 339.912 z_norm:   2.888
# Langevin posterior  10/ 10: LOSS G= 271.583 z_norm:   2.901
# Langevin posterior   1/ 10: LOSS G= 340.206 z_norm:   2.841
# Langevin posterior  10/ 10: LOSS G= 229.511 z_norm:   2.854
# Langevin posterior   1/ 10: LOSS G= 463.285 z_norm:   2.855
# Langevin posterior  10/ 10: LOSS G= 351.080 z_norm:   2.913
# Langevin posterior   1/ 10: LOSS G= 409.745 z_norm:   2.859
# Langevin posterior  10/ 10: LOSS G= 291.027 z_norm:   2.880
# Langevin posterior   1/ 10: LOSS G= 486.890 z_norm:   2.917
# Langevin posterior  10/ 10: LOSS G= 373.475 z_norm:   2.928
# Langevin posterior   1/ 10: LOSS G= 425.828 z_norm:   2.882
# Langevin posterior  10/ 10: LOSS G= 292.480 z_norm:   2.876
# Langevin posterior   1/ 10: LOSS G= 482.395 z_norm:   2.983
# Langevin posterior  10/ 10: LOSS G= 369.478 z_norm:   2.998
# Langevin posterior   1/ 10: LOSS G= 308.128 z_norm:   2.787
# Langevin posterior  10/ 10: LOSS G= 250.701 z_norm:   2.782
# Langevin posterior   1/ 10: LOSS G= 413.621 z_norm:   2.782
# Langevin posterior  10/ 10: LOSS G= 313.085 z_norm:   2.804
# Langevin posterior   1/ 10: LOSS G= 348.345 z_norm:   2.793
# Langevin posterior  10/ 10: LOSS G= 278.944 z_norm:   2.802
# Langevin posterior   1/ 10: LOSS G= 369.292 z_norm:   2.871
# Langevin posterior  10/ 10: LOSS G= 273.452 z_norm:   2.879
# Langevin posterior   1/ 10: LOSS G= 385.927 z_norm:   2.860
# Langevin posterior  10/ 10: LOSS G= 287.534 z_norm:   2.875
# Langevin posterior   1/ 10: LOSS G= 397.392 z_norm:   2.837
# Langevin posterior  10/ 10: LOSS G= 254.054 z_norm:   2.861
# Langevin posterior   1/ 10: LOSS G= 390.804 z_norm:   2.843
# Langevin posterior  10/ 10: LOSS G= 299.653 z_norm:   2.844
# Langevin posterior   1/ 10: LOSS G= 419.873 z_norm:   2.910
# Langevin posterior  10/ 10: LOSS G= 342.513 z_norm:   2.927
# Langevin posterior   1/ 10: LOSS G= 368.450 z_norm:   2.864
# Langevin posterior  10/ 10: LOSS G= 244.796 z_norm:   2.888
# Langevin posterior   1/ 10: LOSS G= 451.208 z_norm:   2.901
# Langevin posterior  10/ 10: LOSS G= 273.729 z_norm:   2.925
# Langevin posterior   1/ 10: LOSS G= 347.827 z_norm:   3.012
# Langevin posterior  10/ 10: LOSS G= 270.387 z_norm:   3.028
# Langevin posterior   1/ 10: LOSS G= 375.613 z_norm:   2.985
# Langevin posterior  10/ 10: LOSS G= 261.878 z_norm:   2.989
# Langevin posterior   1/ 10: LOSS G= 427.173 z_norm:   2.972
# Langevin posterior  10/ 10: LOSS G=3694.006 z_norm:   5.288
# Langevin posterior   1/ 10: LOSS G= 498.923 z_norm:   3.360
# Langevin posterior  10/ 10: LOSS G= 333.509 z_norm:   3.359
# Langevin posterior   1/ 10: LOSS G= 498.346 z_norm:   3.679
# Langevin posterior  10/ 10: LOSS G= 263.447 z_norm:   3.668
# Langevin posterior   1/ 10: LOSS G= 646.424 z_norm:   3.948
# Langevin posterior  10/ 10: LOSS G= 340.895 z_norm:   3.940
# Langevin posterior   1/ 10: LOSS G= 410.683 z_norm:   4.224
# Langevin posterior  10/ 10: LOSS G= 315.120 z_norm:   4.229
# Langevin posterior   1/ 10: LOSS G= 364.436 z_norm:   4.439
# Langevin posterior  10/ 10: LOSS G= 292.397 z_norm:   4.442
# Langevin posterior   1/ 10: LOSS G= 520.839 z_norm:   4.688
# Langevin posterior  10/ 10: LOSS G= 342.391 z_norm:   4.694
# Langevin posterior   1/ 10: LOSS G= 650.357 z_norm:   4.923
# Langevin posterior  10/ 10: LOSS G= 307.278 z_norm:   4.937
# Langevin posterior   1/ 10: LOSS G= 546.547 z_norm:   5.058
# Langevin posterior  10/ 10: LOSS G= 245.585 z_norm:   5.058
# Langevin posterior   1/ 10: LOSS G= 708.430 z_norm:   5.449
# Langevin posterior  10/ 10: LOSS G= 327.973 z_norm:   5.452
# Langevin posterior   1/ 10: LOSS G= 521.325 z_norm:   5.629
# Langevin posterior  10/ 10: LOSS G= 308.756 z_norm:   5.635
# Langevin posterior   1/ 10: LOSS G= 416.746 z_norm:   5.896
# Langevin posterior  10/ 10: LOSS G= 289.335 z_norm:   5.889
# Langevin posterior   1/ 10: LOSS G= 690.026 z_norm:   5.919
# Langevin posterior  10/ 10: LOSS G= 465.247 z_norm:   5.907
# Langevin posterior   1/ 10: LOSS G= 416.173 z_norm:   6.187
# Langevin posterior  10/ 10: LOSS G= 256.707 z_norm:   6.172
# Langevin posterior   1/ 10: LOSS G= 698.382 z_norm:   6.230
# Langevin posterior  10/ 10: LOSS G= 338.510 z_norm:   6.218
# Langevin posterior   1/ 10: LOSS G= 496.592 z_norm:   6.167
# Langevin posterior  10/ 10: LOSS G= 262.340 z_norm:   6.148
# Langevin posterior   1/ 10: LOSS G= 488.665 z_norm:   6.108
# Langevin posterior  10/ 10: LOSS G= 270.912 z_norm:   6.101
# Langevin posterior   1/ 10: LOSS G= 480.834 z_norm:   6.127
# Langevin posterior  10/ 10: LOSS G= 313.242 z_norm:   6.133
# Langevin posterior   1/ 10: LOSS G= 420.299 z_norm:   6.183
# Langevin posterior  10/ 10: LOSS G= 267.915 z_norm:   6.188
# Langevin posterior   1/ 10: LOSS G= 501.438 z_norm:   6.140
# Langevin posterior  10/ 10: LOSS G= 301.111 z_norm:   6.135
# Langevin posterior   1/ 10: LOSS G= 326.393 z_norm:   6.066
# Langevin posterior  10/ 10: LOSS G= 252.468 z_norm:   6.066
# Langevin posterior   1/ 10: LOSS G= 411.961 z_norm:   6.069
# Langevin posterior  10/ 10: LOSS G= 298.657 z_norm:   6.064
# Langevin posterior   1/ 10: LOSS G= 399.764 z_norm:   6.087
# Langevin posterior  10/ 10: LOSS G= 287.255 z_norm:   6.078
# Langevin posterior   1/ 10: LOSS G= 424.666 z_norm:   6.090
# Langevin posterior  10/ 10: LOSS G= 271.488 z_norm:   6.086
# Langevin posterior   1/ 10: LOSS G= 379.578 z_norm:   5.974
# Langevin posterior  10/ 10: LOSS G= 266.254 z_norm:   5.980
# Langevin posterior   1/ 10: LOSS G= 449.019 z_norm:   5.913

# %%
a = torch.randn(16,128)

# %%
torch.mean(torch.linalg.vector_norm(a, dim = 1))

# %%
batch_size
